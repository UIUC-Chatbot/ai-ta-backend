# %% [markdown]
# # Example usage of the UIUC.chat public API
#
#
# ### Available models
#
# model_id must be one of:
# ```text
#     'gpt-3.5-turbo'
#     'gpt-3.5-turbo-16k'
#     'gpt-4'
#     'gpt-4-1106-preview'
#     'gpt-4-vision-preview'
#     'gpt-4-from-canada-east' # Only for use with CAII Azure key
# ```
#
# The last model is an Azure model, and we only suport gpt-4 (regular 8k), and only using our one particular azure key (to avoid a larger rewrite to support all the azure variables).

# %%
import os
import sys

# Add the our library to the Python path
current_dir = os.path.dirname(os.path.abspath(''))
one_dir_up = os.path.dirname(current_dir) # Go up a directory
sys.path.append(one_dir_up)

from ai_ta_backend.public_api.uiuc_chat_api import call_chat_endpoint
from ai_ta_backend.vector_database import Ingest

# %%
### Only necessary to changes: 
user_prompt = "What's in these documents? Use one sentence."
course_name = "test-video-ingest-21"
openai_api_key = '' # Your OpenAI API key
###

system_prompt = "You are a helpful assistant."
token_limit = 6000 # max tokens returned by getTopContexts
stream = True

ingester = Ingest()
found_documents = ingester.getTopContexts(user_prompt, course_name, token_limit)

model_response = call_chat_endpoint(
  model_id="gpt-4-1106-preview",
  messages=[
    {
      "role": "system", 
      "content": [{"type": "text", "text": system_prompt}],
    },
    {
      "role": "user", 
      "content": [{"type": "text", "text": user_prompt}],
      "contexts": found_documents
    }
  ],
  openai_api_key=openai_api_key,
  course_name=course_name,
  stream=stream
)

print("🧠 Final response:")
if stream:
  for message in model_response:
    print(message, end='')
else: 
  print(model_response)
# Out:
# 2023-12-13 17:28:35,801:INFO - HTTP Request: POST http://ec2-18-204-198-136.compute-1.amazonaws.com:6333/collections/uiuc-chatbot-quantized/points/search "HTTP/1.1 200 OK"
# found_docs [Document(page_content='Notion – The all-in-one workspace for your notes, tasks, wikis, and databases.', metadata={'base_url': '', 'chunk_index': 0, 'course_name': 'test-video-ingest-21', 'pagenumber': '', 'readable_filename': 'Notion', 's3_path': 'courses/test-video-ingest-21/aa05eaab-cbcd-4965-9985-073565210515-Notion.html', 'timestamp': '', 'url': 'https://kastanday.notion.site/Neural-networks-ignoring-training-data-the-astonishing-power-of-Attention-c1e4cdb15e9d4583be6e210bf0c98e80'}), Document(page_content='Full papers: Submissions are limited to 12 pages. The 12-page limit includes figures, tables, appendices,\r\n\t\t\t\tand references.\nAbstracts: Submissions are limited to 4 pages (including references). The 4-page limit includes the description of a novel tool/science workflow/concept, and a link of a repository in which the novel source-code of the tool is stored. This repository will need to specify all the instructions necessary to execute the tool, so reviewers can test it. Abstracts will be compiled into a single paper and published as part of the workshop proceedings.\n\n\r\n\t\t\tThe format of the paper should follow ACM manuscript guidelines. Templates are available from\r\n\t\t\tthis link.\r\n\t\t\tFor Latex users, version 1.90 (last update April 4, 2023) is the latest template, and please use the “sigconf” option.\r\n\t\t\nSubmit Your Abstract or Paper\n\n\n\n\n\nOrganization\nGeneral Chairs\n\n\n\nSilvina Caino-Lores\nFrench Institute for Research in Computer Science and Automation (INRIA), France\n\n\n\nAnirban Mandal\nRenaissance Computing Institute (RENCI), UNC Chapel Hill, USA\n\n\nSteering Committee\n\n\n\nDavid Abramson\nUniversity of Queensland, Australia\n\n\n\nMalcolm Atkinson\nUniversity of Edinburgh, UK\n\n\n\nEwa Deelman\nUniversity of Southern California, USA\n\n\n\nMichela Taufer\nUniversity of Tennessee, USA\n\n\nProgram Committee\n\n\nIlkay Altintas\n\n\r\n\t\t\t\t\tSan Diego Supercomputing Center\r\n\t\t\t\t\n\n\nIvona Brandic\n\n\r\n\t\t\t\t\tTechnical University of Vienna\r\n\t\t\t\t\n\n\nJesus Carretero\n\n\r\n\t\t\t\t\tUniversity Carlos III of Madrid\r\n\t\t\t\t\n\n\nAlberto Cascajo\n\n\r\n\t\t\t\t\tUniversity Carlos III of Madrid\r\n\t\t\t\t\n\n\nKyle Chard\n\n\r\n\t\t\t\t\tUniversity of Chicago\r\n\t\t\t\t\n\n\nTainã Coleman\n\n\r\n\t\t\t\t\tUniversity of Southern California\r\n\t\t\t\t\n\n\nEwa Deelman\n\n\r\n\t\t\t\t\tUniversity of Southern California\r\n\t\t\t\t\n\n\nVincenzo de Maio\n\n\r\n\t\t\t\t\tTechnical University of Vienna\r\n\t\t\t\t\n\n\nFrank di Natale\n\n\r\n\t\t\t\t\tNvidia\r\n\t\t\t\t\n\n\nRosa Filgueira\n\n\r\n\t\t\t\t\tUniversity of St. Andrews\r\n\t\t\t\t\n\n\nDaniel Garijo\n\n\r\n\t\t\t\t\tUniversidad Politécnica de Madrid\r\n\t\t\t\t\n\n\nSandra Gesing\n\n\r\n\t\t\t\t\tUniversity of Illinois Chicago\r\n\t\t\t\t\n\n\nTristan Glatard\n\n\r\n\t\t\t\t\tConcordia University\r\n\t\t\t\t\n\n\nWilliam Godoy\n\n\r\n\t\t\t\t\tOak Ridge National Laboratory\r\n\t\t\t\t\n\n\nShantenu Jha\n\n\r\n\t\t\t\t\tRutgers University\r\n\t\t\t\t\n\n\nDaniel S. Katz\n\n\r\n\t\t\t\t\tUniversity of Illinois at Urbana-Champaign\r\n\t\t\t\t\n\n\nTamas Kiss\n\n\r\n\t\t\t\t\tUniversity of Westminster\r\n\t\t\t\t\n\n\nJakob Luettgau\n\n\r\n\t\t\t\t\tUniversity of Tennessee\r\n\t\t\t\t\n\n\nKetan C. Maheshwari\n\n\r\n\t\t\t\t\tOak Ridge National Laboratory\r\n\t\t\t\t\n\n\nPaolo Missier\n\n\r\n\t\t\t\t\tNewcastle University\r\n\t\t\t\t\n\n\nRaffaele Montella\n\n\r\n\t\t\t\t\tUniversity of Naples Parthenope\r\n\t\t\t\t\n\n\nBogdan Nicolae\n\n\r\n\t\t\t\t\tArgonne National Laboratory\r\n\t\t\t\t\n\n\nPaola Olaya\n\n\r\n\t\t\t\t\tUniversity of Tennessee\r\n\t\t\t\t\n\n\nTom Peterka\n\n\r\n\t\t\t\t\tArgonne National Laboratory\r\n\t\t\t\t\n\n\nLoïc Pottier\n\n\r\n\t\t\t\t\tLawrence Livermore National Laboratory\r\n\t\t\t\t\n\n\nRadu Prodan\n\n\r\n\t\t\t\t\tUniversity of Klagenfurt\r\n\t\t\t\t\n\n\nOmer Rana', metadata={'base_url': '', 'chunk_index': 6, 'course_name': 'test-video-ingest-21 ...
# token_counter: 151, num_tokens: 25, max_tokens: 6000
# token_counter: 176, num_tokens: 718, max_tokens: 6000
# token_counter: 894, num_tokens: 17, max_tokens: 6000
# token_counter: 911, num_tokens: 242, max_tokens: 6000
# token_counter: 1153, num_tokens: 919, max_tokens: 6000
# token_counter: 2072, num_tokens: 848, max_tokens: 6000
# token_counter: 2920, num_tokens: 815, max_tokens: 6000
# token_counter: 3735, num_tokens: 432, max_tokens: 6000
# token_counter: 4167, num_tokens: 86, max_tokens: 6000
# token_counter: 4253, num_tokens: 67, max_tokens: 6000
# token_counter: 4320, num_tokens: 345, max_tokens: 6000
# token_counter: 4665, num_tokens: 711, max_tokens: 6000
# token_counter: 5376, num_tokens: 85, max_tokens: 6000
# token_counter: 5461, num_tokens: 18, max_tokens: 6000
# token_counter: 5479, num_tokens: 814, max_tokens: 6000
# Total tokens used: 5479 total docs: 80 num docs used: 14
# Course: test-video-ingest-21 ||| search_query: What's in these documents? Use one sentence.
# ⏰ ^^ Runtime of getTopContexts: 0.78 seconds
# Final response:
# The documents contain information about a productivity tool, a workshop on scientific workflows, a content management system, a fake news detection project, book reviews and publications by an individual, a software development platform, a mnemonic learning medium, machine learning workload management, a content reporting system, and a JavaScript-based AI application.
